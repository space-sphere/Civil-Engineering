# %%
import numpy as np
import pandas as pd
from data_pre import data_normalize
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\program\pycharm\model\Data\out.csv")

# %%
wd = pd.DataFrame(columns=['WD'], index=df['WD'].unique().tolist())
for i in df['WD'].unique():
    wd.loc[i, 'WD'] = df['WD'].tolist().count(i)
wd.plot.bar()
# Out:
# <AxesSubplot:>

# %%
wlc = pd.DataFrame(columns=['WLC'], index=df['WLC'].unique().tolist())
for i in df['WLC'].unique():
    wlc.loc[i, 'WLC'] = df['WLC'].tolist().count(i)
wlc.plot.bar(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                WD         WLC         WLA         WIA          TD          TI  \
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean     3.006623    2.337748    6.436119    4.441589   44.399728   10.138046
# std      0.969513    1.159813    6.276364    3.363534   28.666490    7.364345
# min      1.000000    1.000000    0.000000    0.000000    1.046000    0.000000
# 25%      2.000000    1.000000    0.790000    2.015000   24.370000    3.680000
# 50%      3.000000    2.000000    6.040000    3.620000   39.743000    9.340000
# 75%      4.000000    3.000000   10.142500    6.480000   65.115000   15.266000
# max      5.000000    5.000000   26.593000   12.350000  106.530000   27.350000
#
#               UCS         MTL          TN         ATI         TBD
# count  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    31.159205    1.279384   13.976821    0.229377  202.781457
# std     17.084524    0.404341    4.658357    0.186431   90.685971
# min      3.240000    0.200000    2.000000    0.050000   11.000000
# 25%     16.665000    0.980000   12.000000    0.100000  149.500000
# 50%     33.360000    1.350000   15.000000    0.150000  204.000000
# 75%     45.660000    1.637500   18.000000    0.230000  265.000000
# max     66.850000    1.890000   22.500000    0.712500  367.000000

# %%
na = 'WLA'
wla = []
k = 0
wla_ = []
while k < 27:
    k += 3
    wla.append(len(df[(df[na] < k) & (df[na] >= k - 3)][na].tolist()))
    wla_.append('{}-{}'.format(k-3, k))
df_wla = pd.DataFrame(columns=['WLA'], index=wla_)
df_wla['WLA'] = wla
df_wla.plot.bar()
# Out:
# <AxesSubplot:>

# %%
na = 'WIA'
wia = []
k = 0
wia_ = []
while k < 13:
    k += 1
    wia.append(len(df[(df[na] < k) & (df[na] >= k - 1)][na].tolist()))
    wia_.append('{}-{}'.format(k-1, k))
df_wia = pd.DataFrame(columns=['WIA'], index=wia_)
df_wia['WIA'] = wia
df_wia.plot.bar()
# Out:
# <AxesSubplot:>

# %%
na = 'TD'
td = []
k = 0
td_ = []
while k < 110:
    k += 10
    td.append(len(df[(df[na] < k) & (df[na] >= k - 10)][na].tolist()))
    td_.append('{}-{}'.format(k-10, k))
df_td = pd.DataFrame(columns=['TD'], index=td_)
df_td['TD'] = td
df_td
# Out:
#          count
# 0-10        15
# 10-20       18
# 20-30       21
# 30-40       25
# 40-50       13
# 50-60       13
# 60-70       18
# 70-80       10
# 80-90        2
# 90-100       9
# 100-110      7

# %%
na = 'TI'
ti = []
ti_ = []
k = 0
while k < 30:
    k += 3
    ti.append(len(df[(df[na] < k) & (df[na] >= k - 3)][na].tolist()))
    ti_.append('{}-{}'.format(k-3, k))
df_ti = pd.DataFrame(index=ti_, columns=['TI'])
df_ti['TI'] = ti
df_ti
# Out:
#        count
# 0-3       24
# 3-6       21
# 6-9       30
# 9-12      31
# 12-15      7
# 15-18     13
# 18-21      9
# 21-24      5
# 24-27      7
# 27-30      4

# %%
na = 'UCS'
ucs = []
k = 0
ucs_ = []
while k < 70:
    k += 7
    ucs.append(len(df[(df[na] < k) & (df[na] >= k - 7)][na].tolist()))
    ucs_.append('{}-{}'.format(k-7, k))
df_ucs = pd.DataFrame(columns=['UCS'], index=ucs_)
df_ucs['UCS']=ucs
df_ucs
# Out:
#        count
# 0-7       15
# 7-14      11
# 14-21     26
# 21-28     14
# 28-35     21
# 35-42     15
# 42-49     24
# 49-56     14
# 56-63      9
# 63-70      2

# %%
na = 'MTL'
mtl = []
k = 0
mtl_ = []
while k < 2:
    k += 0.2
    mtl.append(len(df[(df[na] < k) & (df[na] >= k - 0.2)][na].tolist()))
    mtl_.append('{}-{}'.format(round(k-0.2, 1), round(k, 1)))
df_mtl = pd.DataFrame(columns=['MTL'], index=mtl_)
df_mtl['MTL']=mtl
df_mtl
# Out:
#          count
# 0.0-0.2      0
# 0.2-0.4      2
# 0.4-0.6      6
# 0.6-0.8      9
# 0.8-1.0     21
# 1.0-1.2     27
# 1.2-1.4     17
# 1.4-1.6     29
# 1.6-1.8     25
# 1.8-2.0     13
# 2.0-2.2      0

# %%
tn = pd.DataFrame(columns=['TN'], index=df['TN'].unique().tolist())
for i in df['TN'].unique():
    tn.loc[i, 'TN'] = df['TN'].tolist().count(i)
tn
# Out:
#        TN
# 2.00    6
# 7.00    7
# 15.00   4
# 18.00  20
# 14.00  14
# 17.00  16
# 9.00    8
# 19.00  16
# 8.00    6
# 13.00   8
# 16.00  18
# 12.00  12
# 20.00   3
# 6.00    5
# 11.00   4
# 13.75   1
# 22.50   2
# 8.75    1

# %%
na = 'ATI'
ati = []
k = 0
ati_ = []
while k < 0.75:
    k += 0.15
    ati.append(len(df[(df[na] < k) & (df[na] >= k - 0.15)][na].tolist()))
    ati_.append('{}-{}'.format(round(k-0.15, 2), round(k, 2)))
df_ati = pd.DataFrame(columns=['ATI'], index=ati_)
df_ati['ATI']=ati
df_ati
# Out:
#           count
# 0.0-0.15     69
# 0.15-0.3     46
# 0.3-0.45      4
# 0.45-0.6     28
# 0.6-0.75      4

# %%
na = 'TBD'
tbd = []
k = 0
tbd_ = []
while k < 400:
    k += 50
    tbd.append(len(df[(df[na] < k) & (df[na] >= k - 50)][na].tolist()))
    tbd_.append('{}-{}'.format(k-50, k))
df_tbd = pd.DataFrame(columns=['TBD'], index=tbd_)
df_tbd['TBD']=tbd
df_tbd
# Out:
#          count
# 0-50        12
# 50-100      14
# 100-150     12
# 150-200     30
# 200-250     37
# 250-300     18
# 300-350     18
# 350-400     10

# %%
df_tbd.plot.bar()
# Out:
# <AxesSubplot:>

# %%
with pd.ExcelWriter(r"C:\Users\42253\Downloads\Out.xlsx") as writer:
    wd.to_excel(writer, sheet_name='WD', index=True)
    wlc.to_excel(writer, sheet_name='WLC', index=True)
    df_wla.to_excel(writer, sheet_name='WLA', index=True)
    df_wia.to_excel(writer, sheet_name='WIA', index=True)
    df_td.to_excel(writer, sheet_name='TD', index=True)
    df_ti.to_excel(writer, sheet_name='TI', index=True)
    df_ucs.to_excel(writer, sheet_name='UCS', index=True)
    df_mtl.to_excel(writer, sheet_name='MTL', index=True)
    tn.to_excel(writer, sheet_name='TN', index=True)
    df_ati.to_excel(writer, sheet_name='ATI', index=True)
    df_tbd.to_excel(writer, sheet_name='TBD', index=True)

# %%
df
# Out:
#      WD  WLC     WLA     WIA      TD      TI    UCS    MTL     TN    ATI  TBD
# 0     1    1   0.000   0.000   1.360   1.290  52.64  0.200   2.00  0.680   11
# 1     4    1  10.100  12.350  99.120  26.890  10.20  0.500   7.00  0.550   20
# 2     3    3   8.900  10.230  63.440  18.640  32.00  1.200  15.00  0.320   40
# 3     2    2   4.300   6.010  35.660  11.560  50.56  1.700  18.00  0.100  350
# 4     2    1   0.000   0.000   2.360   3.570  60.25  1.400  14.00  0.180  221
# ..   ..  ...     ...     ...     ...     ...    ...    ...    ...    ...  ...
# 146   2    2  16.858   8.028  56.476  10.459  11.94  1.760  19.00  0.110  196
# 147   4    3   7.214   3.461  65.889  25.101  21.86  1.490  11.00  0.126  167
# 148   3    3  22.491   2.869  30.330  11.504  16.99  1.350  15.00  0.320  204
# 149   2    4  24.662   6.223  89.944  21.963   7.29  0.980   6.00  0.560   26
# 150   5    1   0.000   0.000  49.155   6.275  17.89  1.095   8.75  0.150  182
#
# [151 rows x 11 columns]

# %%
plt.figure(figsize=(5, 6))
df['WLC'].plot.hist(figsize=(5, 5), edgecolor='w')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.figure(figsize=(5, 6))
#       2 df['WLC'].plot.hist(figsize=(5, 5), edgecolor='w')
#
# TypeError: 'Figure' object is not callable

# %%
fig = plt.figure(figsize=(5, 6))

# %%
fig1 = fig.add_subplot(121)
df['WLC'].plot.hist(figsize=(5, 5), edgecolor='w')
fig1.grid()
fig1.set_ylabel('')
fig1.set_xlabel('WLC')
# fig2 = fig.add_subplot(122)
# plt.grid()
# df['WLA'].plot.hist(edgecolor='w')
# Out:
# Text(0.5, 0, 'WLC')

# %%
df.iloc[:, 1:].hist(layout=(2, 5), figsize=(15, 6), edgecolor='w')
# Out:
# array([[<AxesSubplot:title={'center':'WLC'}>,
#         <AxesSubplot:title={'center':'WLA'}>,
#         <AxesSubplot:title={'center':'WIA'}>,
#         <AxesSubplot:title={'center':'TD'}>,
#         <AxesSubplot:title={'center':'TI'}>],
#        [<AxesSubplot:title={'center':'UCS'}>,
#         <AxesSubplot:title={'center':'MTL'}>,
#         <AxesSubplot:title={'center':'TN'}>,
#         <AxesSubplot:title={'center':'ATI'}>,
#         <AxesSubplot:title={'center':'TBD'}>]], dtype=object)

# %%
df.iloc[:, 1:].plot.density(subplots=True, layout=(2, 5), figsize=(15, 6))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
import seaborn as sns

sns.histplot(df['WLC'], edgecolor='w')
# Out:
# <AxesSubplot:xlabel='WLC', ylabel='Count'>

# %%
fig, axs = plt.subplots(2, 5, figsize=(30, 10))

fig.subplots_adjust(wspace=0.4, hspace=0.2)

sns.histplot(df['WLC'], ax=axs[0, 0], edgecolor='w')
ax0 = axs[0, 0].twinx()
sns.kdeplot(df['WLC'], ax=ax0, color='orange')

# sns.histplot(df['WLA'], ax=axs[0, 1], edgecolor='w')
# ax1 = axs[0, 1].twinx()
# sns.kdeplot(df['WLA'], ax=ax1)
# 
# sns.histplot(df['WIA'], ax=axs[0, 2], edgecolor='w')
# ax2 = axs[0, 2].twinx()
# sns.kdeplot(df['WIA'], ax=ax2)
# 
# sns.histplot(df['TD'], ax=axs[0, 3], edgecolor='w')
# ax3 = axs[0, 3].twinx()
# sns.kdeplot(df['TD'], ax=ax3)
# 
# sns.histplot(df['TI'], ax=axs[0, 4], edgecolor='w')
# ax4 = axs[0, 4].twinx()
# sns.kdeplot(df['TI'], ax=ax4)
# 
# sns.histplot(df['UCS'], ax=axs[1, 0], edgecolor='w')
# ax5 = axs[1, 0].twinx()
# sns.kdeplot(df['UCS'], ax=ax5)
# 
# sns.histplot(df['MTL'], ax=axs[1, 1], edgecolor='w')
# ax6 = axs[1, 1].twinx()
# sns.kdeplot(df['MTL'], ax=ax6)
# 
# sns.histplot(df['TN'], ax=axs[1, 2], edgecolor='w')
# ax7 = axs[1, 2].twinx()
# sns.kdeplot(df['TN'], ax=ax7)
# 
# sns.histplot(df['ATI'], ax=axs[1, 3], edgecolor='w')
# ax8 = axs[1, 3].twinx()
# sns.kdeplot(df['ATI'], ax=ax8)
# 
# sns.histplot(df['TBD'], ax=axs[1, 4], edgecolor='w')
# ax9 = axs[1, 4].twinx()
# sns.kdeplot(df['TBD'], ax=ax9)

axis = axs[0, 0].axis()
axs[0, 0].text(axis[1] * 2/3, axis[3] * 2/3, 'Min = 1\nMax = 5\nMean = 2.33')

plt.show()

# %%
df.columns[2:]
# Out:
# Index(['WLA', 'WIA', 'TD', 'TI', 'UCS', 'MTL', 'TN', 'ATI', 'TBD'], dtype='object')

# %%
fig, axs = plt.subplots(2, 5, figsize=(30, 10))

n = df.columns[1:]
fig.subplots_adjust(wspace=0.4, hspace=0.2)
for i in range(2):
    for j in range(5):
        sns.histplot(df[n[5 * i + j]], ax=axs[i, j], edgecolor='w')
        sns.kdeplot(df[n[5 * i + j]], ax=axs[i, j].twinx(), color='orange')
        axis = axs[i, j].axis()
        message = df.describe()[n[5 * i + j]]
        axs[i, j].text(axis[1] * 1 / 2, axis[3] * 4 / 5, 'n = {}\nMin = {}\nMax = {}\nMean = {}'.format(message['count'],
                       message['min'], 
                       message['max'], 
                       round(message['mean'], 2)), 
                       # round(message['std'], 2), 
                       fontsize=12)

# %%
from matplotlib.ticker import FormatStrFormatter

fig, axs = plt.subplots(2, 5, figsize=(30, 10))

n = df.columns[1:]
fig.subplots_adjust(wspace=0.3, hspace=0.2)
plt.rcParams['font.sans-serif'] = ['Times New Roman']
plt.rcParams['axes.unicode_minus'] =False
for i in range(2):
    for j in range(5):
        sns.histplot(df[n[5 * i + j]], ax=axs[i, j], edgecolor='w')
        ax = axs[i, j].twinx()
        sns.kdeplot(df[n[5 * i + j]], ax=ax, color='r', linewidth=2.4, legend=False)
        axs[i, j].set_xlabel(n[5 * i + j], weight='bold', fontsize=14)
        axs[i, j].set_ylabel('Count', weight='bold', fontsize=14)
        ax.set_ylabel('Density', weight='bold', fontsize=14)
        y_formatter = FormatStrFormatter('%1.2f')
        ax.yaxis.set_major_formatter(y_formatter)
        axis = axs[i, j].axis()
        message = df.describe()[n[5 * i + j]]
        if j == 0 and i == 1:
            axs[i, j].text(axis[1] * 3/ 5, axis[3] * 2 / 3, 'n = {}\nMin = {}\nMax = {}\nMean = {}\nStd = {}'.format(message['count'],
                       message['min'], 
                       message['max'], 
                       round(message['mean'], 2), 
                       round(message['std'], 2)), 
                       fontsize=14)
        elif ((j == 1) | (j == 2)) and (i == 1):
            axs[i, j].text(axis[1] * 1 / 40, axis[3] * 2 / 3, 'n = {}\nMin = {}\nMax = {}\nMean = {}\nStd = {}'.format(message['count'],
                       message['min'], 
                       message['max'], 
                       round(message['mean'], 2), 
                       round(message['std'], 2)), 
                       fontsize=14)
        else:
            axs[i, j].text(axis[1] * 21 / 40, axis[3] * 2 / 3, 'n = {}\nMin = {}\nMax = {}\nMean = {}\nStd = {}'.format(message['count'],
                       message['min'], 
                       message['max'], 
                       round(message['mean'], 2), 
                       round(message['std'], 2)), 
                       fontsize=14)

# %%
df.describe()
# Out:
#                WD         WLC         WLA         WIA          TD          TI  \
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean     3.006623    2.337748    6.436119    4.441589   44.399728   10.138046
# std      0.969513    1.159813    6.276364    3.363534   28.666490    7.364345
# min      1.000000    1.000000    0.000000    0.000000    1.046000    0.000000
# 25%      2.000000    1.000000    0.790000    2.015000   24.370000    3.680000
# 50%      3.000000    2.000000    6.040000    3.620000   39.743000    9.340000
# 75%      4.000000    3.000000   10.142500    6.480000   65.115000   15.266000
# max      5.000000    5.000000   26.593000   12.350000  106.530000   27.350000
#
#               UCS         MTL          TN         ATI         TBD
# count  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    31.159205    1.279384   13.976821    0.229377  202.781457
# std     17.084524    0.404341    4.658357    0.186431   90.685971
# min      3.240000    0.200000    2.000000    0.050000   11.000000
# 25%     16.665000    0.980000   12.000000    0.100000  149.500000
# 50%     33.360000    1.350000   15.000000    0.150000  204.000000
# 75%     45.660000    1.637500   18.000000    0.230000  265.000000
# max     66.850000    1.890000   22.500000    0.712500  367.000000
