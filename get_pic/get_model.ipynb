# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/test_pred.csv', encoding='gbk')
df
# Out:
#     真实值  gbrt预测值  xgb预测值  svm真实值  mlp预测值  rfc预测值
# 0     4        2       3       3       3       3
# 1     4        2       3       3       2       2
# 2     2        2       3       3       2       2
# 3     2        2       2       4       2       2
# 4     2        2       2       3       4       2
# ..  ...      ...     ...     ...     ...     ...
# 90    3        3       3       3       4       3
# 91    2        4       4       4       2       2
# 92    3        3       3       3       4       3
# 93    3        3       3       3       2       3
# 94    4        5       4       4       4       2
#
# [95 rows x 6 columns]

# %%
df_1 = pd.DataFrame()
df_1['gbrt'] = df['gbrt预测值'] - df['真实值']
df_1['xgb'] = df['xgb预测值'] - df['真实值']
df_1['svm'] = df['svm真实值'] - df['真实值']
df_1['mlp'] = df['mlp预测值'] - df['真实值']
df_1['rfc'] = df['rfc预测值'] - df['真实值']
df_1
# Out:
#     gbrt  xgb  svm  mlp  rfc
# 0     -2   -1   -1   -1   -1
# 1     -2   -1   -1   -2   -2
# 2      0    1    1    0    0
# 3      0    0    2    0    0
# 4      0    0    1    2    0
# ..   ...  ...  ...  ...  ...
# 90     0    0    0    1    0
# 91     2    2    2    0    0
# 92     0    0    0    1    0
# 93     0    0    0   -1    0
# 94     1    0    0    0   -2
#
# [95 rows x 5 columns]

# %%
df_1.describe()
# Out:
#             gbrt        xgb        svm        mlp        rfc
# count  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    0.115789   0.221053   0.147368  -0.031579   0.000000
# std     0.697460   0.760444   0.967212   1.015336   0.978492
# min    -2.000000  -1.000000  -2.000000  -2.000000  -2.000000
# 25%     0.000000   0.000000  -0.500000  -1.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   1.000000   0.000000   0.000000
# max     3.000000   2.000000   2.000000   2.000000   2.000000

# %%
(df_1 == 0).sum(0) / 95
# Out:
# gbrt    0.810526
# xgb     0.757895
# svm     0.431579
# mlp     0.515789
# rfc     0.715789
# dtype: float64

# %%
df_1.plot.box()
# Out:
# <Axes: >
